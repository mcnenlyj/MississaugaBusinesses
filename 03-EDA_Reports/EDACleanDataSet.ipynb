# %%
# !pip install pandas-profiling==3.5.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Using cached pandas_profiling-3.5.0-py2.py3-none-any.whl (325 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.7/102.7 KB 5.7 MB/s eta 0:00:00
# ...
#   Using cached scipy-1.9.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (33.8 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 KB 9.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 20.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.65.0
#     Uninstalling tqdm-4.65.0:
#       Successfully uninstalled tqdm-4.65.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.10.1
#     Uninstalling scipy-1.10.1:
#       Successfully uninstalled scipy-1.10.1
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
# ...

# %%
import numpy as np
import pandas as pd
from pandas_profiling import ProfileReport

df = pd.read_csv("/content/drive/MyDrive/CIND 820 Capstone Project/merged_completedata.csv")

# %%
profile = ProfileReport(df)

# %%
# Produce the data profiling report
original_report = ProfileReport(df, title='Combined Data 2016 to 2021 Mississauga Business Directory')
original_report.to_file("/content/drive/MyDrive/CIND 820 Capstone Project/EDACleanData.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
